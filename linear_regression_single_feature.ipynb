# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvasree07/machine_learning/blob/main/linear_regression_single_feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear regression model 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# <ipython-input-1-51c1d4841fc1>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
ds=pd.read_csv("/content/train.csv")
ds
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 695  58  58.595006
# 696  93  94.625094
# 697  82  88.603770
# 698  66  63.648685
# 699  97  94.975266
#
# [700 rows x 2 columns]

# %%
ds.describe()
# Out:
#                 x           y
# count  700.000000  700.000000
# mean    49.992857   49.911608
# std     28.939406   29.097996
# min      0.000000   -3.839981
# 25%     25.000000   24.985830
# 50%     49.000000   48.936330
# 75%     75.000000   74.880631
# max    100.000000  108.871618

# %%
print(ds['y'].shape)
# Out:
# (700,)

# %%
print(ds)
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 695  58  58.595006
# 696  93  94.625094
# 697  82  88.603770
# 698  66  63.648685
# 699  97  94.975266
#
# [700 rows x 2 columns]

# %%
theta0=0
theta1=0
def hypothesis(x1,theta0,theta1):
  return (theta0 + theta1*x1)

# %%
plt.scatter(ds['x'],ds['y'])
plt.plot(ds['x'],hypothesis(ds['x'],theta0,theta1))
plt.xlim(-5,105)
# Out:
# (-5.0, 105.0)

# %%
def gradient_theta0(theta0,theta1):
  sum1=0
  for i in range(len(ds['x'])):
    sum1+=(hypothesis(ds['x'][i],theta0,theta1)-ds['y'][i])
  return(sum1 / 700)

# %%
gradient_theta0(0,0)
# Out:
# -49.91160792878568

# %%
def gradient_theta1(theta0,theta1):
  sum2=0
  for i in range(len(ds['x'])):
    sum2+=(hypothesis(ds['x'][i],theta0,theta1) - ds['y'][i]) * ds['x'][i]
  return (sum2 / 700)

# %%
gradient_theta1(0,0)
# Out:
# -3332.1675422549415

# %%
def linear(learning_rate):
  theta0_temp=0
  theta1_temp=0
  theta0=0
  theta1=0
  t1=[]
  t0=[]
  plt.scatter(ds['x'],ds['y'])
  for i in range(300):
    theta0_temp=theta0 - learning_rate * (gradient_theta0(theta0,theta1))
    theta1_temp=theta1 - learning_rate * (gradient_theta1(theta0,theta1))
    print(theta0_temp,theta1_temp)
    theta1=theta1_temp
    theta0=theta0_temp
    t1.append(theta1)
    t0.append(theta0)
    plt.plot(ds['x'],hypothesis(ds['x'],theta0,theta1))
  print(t1,t0)
  return theta0,theta1

# %%
theta0_list,theta1_list=linear(0.0001)
# Out:
# 0.004991160792878568 0.3332167542254942
# 0.008315976710517689 0.5552614897085846
# 0.010530395072532082 0.703224837329363
# 0.01200488094271182 0.8018227772719883
# 0.012986300091691374 0.8675252282725048
# 0.01363915577407559 0.9113072041135241
# 0.014073067564526358 0.9404820940994463
# 0.014361082353075602 0.9599233010502704
# 0.014551876191968264 0.9728783008020889
# 0.014677885206289196 0.9815111047644914
# 0.014760723766185228 0.9872637391809954
# 0.014814794979167333 0.991097123054975
# 0.01484969660378958 0.9936515813009014
# 0.014871824271632765 0.9953538054449622
# 0.014885439821863251 0.9964881287286196
# 0.014893383204351344 0.9972440215004472
# 0.014897546868565458 0.9977477405878357
# 0.014899191880775558 0.9980834194004858
# 0.014899158574191766 0.9983071216838141
# 0.014898006919309337 0.9984562064793865
# 0.014896110062103673 0.9985555686274671
# 0.01489371665481629 0.9986217972332839
# 0.014890992391146697 0.9986659467325898
# 0.0148880476839423 0.9986953834388856
# ...

# %%
print(theta0_list,theta1_list)
# Out:
# 0.014631902617044666 0.9987579287601395

# %%
theta0_detail,theta1_detail=linear(0.00001)
# Out:
# 0.0004991160792878568 0.03332167542254942
# 0.0009815687098233194 0.06553163065767482
# 0.001447913838926002 0.09666695633625623
# 0.0018986888656899376 0.12676350562410418
# 0.0023344132598132022 0.15585593550785207
# 0.0027555891597813575 0.18397774670341585
# 0.0031627019510935307 0.21116132223297684
# 0.0035562208251969773 0.23743796471490952
# 0.003936599319773751 0.2628379324095954
# 0.004304275841001642 0.2873904740626302
# 0.0046596741683907796 0.31112386258554725
# 0.00500320394277722 0.3340654276128419
# 0.005335261138035487 0.3562415869727864
# 0.005656228517053211 0.37767787710827555
# 0.005966476072492982 0.39839898248273276
# 0.006266361452848926 0.4184287640049392
# 0.006556230374288642 0.43779028650551727
# 0.006836417018754748 0.4565058452967079
# 0.0071072444187844416 0.4745969918460276
# 0.007369024829490228 0.49208455859336725
# 0.007622060088130149 0.5089886829401116
# 0.007866641961681565 0.5253288304379029
# 0.008103052482818743 0.5411238172037515
# ...

# %%
theta0_det,theta1_det=linear(0.0005)
# Out:
# 0.02495580396439284 1.6660837711274707
# 0.008252986047799307 0.5528670736948562
# 0.019384961202060038 1.296678767713589
# 0.01191873448861112 0.7996910282370838
# 0.01687915941921914 1.1317607447935978
# 0.01353654718672242 0.9098841530595162
# 0.015741728637294936 1.0581345171382506
# 0.014240077860759804 0.9590793907426133
# 0.015215202301195316 1.0252648787510692
# 0.0145354383559421 0.9810425443608275
# 0.014961414715509018 1.0105907371268081
# 0.014648578797006512 0.9908481226978209
# 0.014829394147850693 1.0040398488661781
# 0.014680373050118264 0.9952260357328704
# 0.014751740313363348 1.0011155307048065
# 0.014675855552589021 0.9971808051375813
# 0.0146983628207844 0.9998102695616027
# 0.014655131615689519 0.9980537787907525
# 0.014655828022287114 0.9992278251337126
# 0.014627177115130063 0.998443792157274
# 0.014618138557719781 0.9989680771489405
# 0.01459599926724294 0.9986181911804994
# 0.01458261694602962 0.9988523946846393
# 0.014563387064814498 0.9986963306041343
# ...

# %%
print(theta0_list,theta1_list) # 0.014631902617044666 0.9987579287601395
# Out:
# 0.014631902617044666 0.9987579287601395

# %%
plt.plot(ds['x'],hypothesis(ds['x'],theta0_list,theta1_list),color='blue')
plt.scatter(ds['x'],ds['y'])
plt.plot(ds['x'],hypothesis(ds['x'],theta0_detail,theta1_detail),color='black')
plt.plot(ds['x'],hypothesis(ds['x'],theta0_det,theta1_det),color='orange')

# %%
plt.plot(ds['x'],hypothesis(ds['x'],theta0_list,theta1_list),color='blue')

# %%
dtest=pd.read_csv('/content/test (1).csv')
dtest
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
plt.scatter(dtest['x'],dtest['y'],color='green')
plt.scatter(ds['x'],ds['y'],color='lightpink')

# %%
plt.scatter(dtest['x'],hypothesis(dtest['x'],theta0_list,theta1_list))
plt.scatter(dtest['x'],dtest['y'],color='green')

# %% [markdown]
# r_squared for 0.0001

# %%
r_squared = 1 - np.sum((hypothesis(dtest['x'],theta0_list,theta1_list) - dtest['y'])**2) / np.sum((dtest['y'] - np.mean(dtest['y']))**2)

# %%
r_squared
# Out:
# 0.9887678595839114

# %% [markdown]
# r2squared for 0.00001

# %%
r_squared = 1 - np.sum((hypothesis(dtest['x'],theta0_detail,theta1_detail) - dtest['y'])**2) / np.sum((dtest['y'] - np.mean(dtest['y']))**2)

# %%
r_squared
# Out:
# 0.981922419227138

# %% [markdown]
# r2squared for 0.0005

# %%
r_squared = 1 - np.sum((hypothesis(dtest['x'],theta0_det,theta1_det) - dtest['y'])**2) / np.sum((dtest['y'] - np.mean(dtest['y']))**2)

# %%
r_squared
# Out:
# 0.988768131999809

# %%
dt={'orginal':dtest['y'],'predict':hypothesis(dtest['x'],theta0_list,theta1_list)}
data=pd.DataFrame(dt)
data
# Out:
#        orginal    predict
# 0    79.775152  76.918992
# 1    23.177279  20.988548
# 2    25.609262  21.987306
# 3    17.857388  19.989790
# 4    41.849864  35.969917
# ..         ...        ...
# 295  68.545888  70.926445
# 296  47.334876  45.957497
# 297  54.090637  54.946318
# 298  63.297171  61.937623
# 299  52.459467  46.956255
#
# [300 rows x 2 columns]
